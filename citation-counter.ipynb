# %% [markdown]
# # Scholar.py Citation Counter
# This notebook will use [scholar.py](https://github.com/ckreibich/scholar.py) to fetch citation counts for each DOI in your groups, aggregate by year (2018-2025), and output a summary CSV.

# %%
# Install scholar.py and dependencies
# !git clone https://github.com/ckreibich/scholar.py.git
# !pip install requests lxml
# Out:
# fatal: destination path 'scholar.py' already exists and is not an empty directory.
# Requirement already satisfied: requests in ./.venv/lib/python3.14/site-packages (2.32.5)
# Requirement already satisfied: lxml in ./.venv/lib/python3.14/site-packages (6.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.14/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.14/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.14/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.14/site-packages (from requests) (2025.11.12)
# Requirement already satisfied: requests in ./.venv/lib/python3.14/site-packages (2.32.5)
# Requirement already satisfied: lxml in ./.venv/lib/python3.14/site-packages (6.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.14/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.14/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.14/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.14/site-packages (from requests) (2025.11.12)

# %%
import pandas as pd
import ast
df = pd.read_csv('dois_by_topic.csv')
# Convert string representation of list to actual list
df['doi_list'] = df['doi_list'].apply(ast.literal_eval)
groups = df['doi_list'].tolist()
print(f"Loaded {len(groups)} groups of DOIs.")
# Out:
# Loaded 20 groups of DOIs.

# %%
import subprocess
import os
def get_citations_for_doi(doi):
    # Call scholar.py script using subprocess
    script_path = os.path.join('scholar.py', 'scholar.py') if os.path.isdir('scholar.py') else 'scholar.py'
    try:
        result = subprocess.run(["python3", script_path, "-c", doi], capture_output=True, text=True, timeout=30)
        output = result.stdout
        # Parse citation count from output
        for line in output.splitlines():
            if "Citations" in line:
                try:
                    return int(line.split(':')[-1].strip())
                except ValueError:
                    continue
    except Exception as e:
        print(f"Error fetching citations for DOI {doi}: {e}")
    return 0

# %%
# Test citation counting for group 0 only
test_group_idx = 0
test_doi_list = groups[test_group_idx]
test_total_citations = 0
for doi in test_doi_list:
    try:
        count = get_citations_for_doi(doi)
        print(f"DOI: {doi}, Citations: {count}")
        test_total_citations += count
    except Exception as e:
        print(f"Error for DOI {doi}: {e}")
print(f"Total citations for group {test_group_idx}: {test_total_citations}")
# Out:
# DOI: 10.1111/apa.17349, Citations: 0
# DOI: 10.1038/s41598-024-68467-8, Citations: 0
# DOI: 10.3390/reprodmed1020008, Citations: 0
# DOI: 10.1016/j.dcn.2022.101150, Citations: 0
# DOI: 10.1016/j.dcn.2023.101261, Citations: 0
# DOI: 10.1016/j.dcn.2022.101150, Citations: 0
# DOI: 10.1016/j.dcn.2023.101261, Citations: 0
# DOI: 10.1016/j.jadohealth.2024.06.0, Citations: 0
# DOI: 10.1016/j.ypmed.2023.107452, Citations: 0
# DOI: 10.1016/j.dcn.2023.101227, Citations: 0
# DOI: 10.1016/j.jadohealth.2024.06.0, Citations: 0
# DOI: 10.1016/j.ypmed.2023.107452, Citations: 0
# DOI: 10.1016/j.dcn.2023.101227, Citations: 0
# DOI: 10.1038/s41380-023-02316-4, Citations: 0
# DOI: 10.1007/s00787-024-02620-6, Citations: 0
# DOI: 10.1038/s41380-023-02316-4, Citations: 0
# DOI: 10.1007/s00787-024-02620-6, Citations: 0
# DOI: 10.1016/j.addbeh.2024.108211, Citations: 0
# DOI: 10.1007/s10578-019-00892-7, Citations: 0
# DOI: 10.1186/s13293-024-00604-4, Citations: 0
# DOI: 10.1016/j.addbeh.2024.108211, Citations: 0
# DOI: 10.1007/s10578-019-00892-7, Citations: 0
# DOI: 10.1186/s13293-024-00604-4, Citations: 0
# DOI: 10.1186/s12966-019-0862-x, Citations: 0
# DOI: 10.3390/brainsci13101452, Citations: 0
# DOI: 10.1186/s12966-019-0862-x, Citations: 0
# DOI: 10.3390/brainsci13101452, Citations: 0
# DOI: 10.1016/j.comppsych.2024.152509, Citations: 0
# DOI: 10.3389/fendo.2020.549928, Citations: 0
# DOI: 10.1016/j.dcn.2023.101220, Citations: 0
# DOI: 10.1016/j.comppsych.2024.152509, Citations: 0
# DOI: 10.3389/fendo.2020.549928, Citations: 0
# DOI: 10.1016/j.dcn.2023.101220, Citations: 0
# DOI: 10.1007/s00127-024-02669-3, Citations: 0
# DOI: 10.1037/hea0001251, Citations: 0
# DOI: 10.1007/s00127-024-02669-3, Citations: 0
# DOI: 10.1037/hea0001251, Citations: 0
# DOI: 10.1186/s12889-020-09894-w, Citations: 0
# DOI: 10.1097/j.pain.0000000000002969, Citations: 0
# DOI: 10.1002/advs.202307540, Citations: 0
# DOI: 10.1186/s12889-020-09894-w, Citations: 0
# DOI: 10.1097/j.pain.0000000000002969, Citations: 0
# DOI: 10.1002/advs.202307540, Citations: 0
# DOI: 10.1016/j.jaac.2024.10.016, Citations: 0
# DOI: 10.1016/j.jaac.2024.10.016, Citations: 0
# DOI: 10.1016/j.dcn.2023.101223, Citations: 0
# DOI: 10.1016/j.bpsc.2024.11.003, Citations: 0
# DOI: 10.1111/jcpp.14139, Citations: 0
# DOI: 10.1016/j.dcn.2023.101223, Citations: 0
# DOI: 10.1016/j.bpsc.2024.11.003, Citations: 0
# DOI: 10.1111/jcpp.14139, Citations: 0
# DOI: 10.1016/j.dcn.2022.101172, Citations: 0
# DOI: 10.1016/j.dcn.2022.101172, Citations: 0
# DOI: 10.1016/j.cortex.2023.09.009, Citations: 0
# DOI: 10.1002/dev.70037, Citations: 0
# DOI: 10.3389/fped.2023.1198033, Citations: 0
# DOI: 10.1016/j.cortex.2023.09.009, Citations: 0
# DOI: 10.1002/dev.70037, Citations: 0
# DOI: 10.3389/fped.2023.1198033, Citations: 0
# DOI: 10.1111/ijpo.12827, Citations: 0
# DOI: 10.1111/ijpo.12827, Citations: 0
# DOI: 10.1016/j.acap.2021.12.008, Citations: 0
# DOI: 10.1016/j.jpeds.2021.08.077, Citations: 0
# DOI: 10.1038/s41390-022-02176-8, Citations: 0
# DOI: 10.1016/j.annepidem.2023.03.004, Citations: 0
# DOI: 10.1016/j.acap.2021.12.008, Citations: 0
# DOI: 10.1016/j.jpeds.2021.08.077, Citations: 0
# DOI: 10.1038/s41390-022-02176-8, Citations: 0
# DOI: 10.1016/j.annepidem.2023.03.004, Citations: 0
# DOI: 10.1016/j.jadohealth.2022.10.023, Citations: 0
# DOI: 10.1016/j.jadohealth.2022.10.023, Citations: 0
# DOI: 10.1016/j.sleh.2023.02.005, Citations: 0
# DOI: 10.1111/jcpp.13673, Citations: 0
# DOI: 10.1016/j.acap.2024.01.023, Citations: 0
# DOI: 10.1016/j.annepidem.2024.04.013, Citations: 0
# DOI: 10.1016/j.sleh.2023.02.005, Citations: 0
# DOI: 10.1111/jcpp.13673, Citations: 0
# DOI: 10.1016/j.acap.2024.01.023, Citations: 0
# DOI: 10.1016/j.annepidem.2024.04.013, Citations: 0
# DOI: 10.1016/j.drugalcdep.2024.112504, Citations: 0
# DOI: 10.1016/j.drugalcdep.2024.112504, Citations: 0
# DOI: 10.1016/j.jadohealth.2024.06.006, Citations: 0
# DOI: 10.1038/s41390-024-03243-y, Citations: 0
# DOI: 10.1186/s12889-024-18790-6, Citations: 0
# DOI: 10.1186/s12889-024-20102-x, Citations: 0
# DOI: 10.1016/j.jadohealth.2024.06.006, Citations: 0
# DOI: 10.1038/s41390-024-03243-y, Citations: 0
# DOI: 10.1186/s12889-024-18790-6, Citations: 0
# DOI: 10.1186/s12889-024-20102-x, Citations: 0
# DOI: 10.1007/s00127-025-02814-6, Citations: 0
# DOI: 10.1016/j.acap.2025.102784, Citations: 0
# DOI: 10.1186/s12887-024-05367-w, Citations: 0
# DOI: 10.1016/j.socscimed.2023.116220, Citations: 0
# DOI: 10.1038/s41598-024-63566-y, Citations: 0
# DOI: 10.1007/s00127-025-02814-6, Citations: 0
# DOI: 10.1016/j.acap.2025.102784, Citations: 0
# DOI: 10.1186/s12887-024-05367-w, Citations: 0
# DOI: 10.1016/j.socscimed.2023.116220, Citations: 0
# DOI: 10.1038/s41598-024-63566-y, Citations: 0
# DOI: 10.1038/s44277-024-00006-9, Citations: 0
# DOI: 10.1016/j.neuroimage.2018.10.040, Citations: 0
# DOI: 10.1111/apa.16253, Citations: 0
# DOI: 10.1186/s12889-023-16111-x, Citations: 0
# DOI: 10.1016/j.jad.2022.05.071, Citations: 0
# DOI: 10.1038/s44277-024-00006-9, Citations: 0
# DOI: 10.1016/j.neuroimage.2018.10.040, Citations: 0
# DOI: 10.1111/apa.16253, Citations: 0
# DOI: 10.1186/s12889-023-16111-x, Citations: 0
# DOI: 10.1016/j.jad.2022.05.071, Citations: 0
# DOI: 10.1093/aje/kwaf062, Citations: 0
# DOI: 10.1038/s41598-022-11341-2, Citations: 0
# DOI: 10.1016/j.jadohealth.2023, Citations: 0
# DOI: 10.1016/j.dcn.2022.101182, Citations: 0
# DOI: 10.1016/j.pmedr.2023.102428, Citations: 0
# DOI: 10.1093/aje/kwaf062, Citations: 0
# DOI: 10.1038/s41598-022-11341-2, Citations: 0
# DOI: 10.1016/j.jadohealth.2023, Citations: 0
# DOI: 10.1016/j.dcn.2022.101182, Citations: 0
# DOI: 10.1016/j.pmedr.2023.102428, Citations: 0
# DOI: 10.1002/oby.24199, Citations: 0
# DOI: 10.1016/j.jaac.2023.02.014, Citations: 0
# DOI: 10.1017/s0954579419000580, Citations: 0
# DOI: 10.1016/j.dcn.2022.101120, Citations: 0
# DOI: 10.1016/j.dcn.2018.03.005, Citations: 0
# DOI: 10.1002/oby.24199, Citations: 0
# DOI: 10.1016/j.jaac.2023.02.014, Citations: 0
# DOI: 10.1017/s0954579419000580, Citations: 0
# DOI: 10.1016/j.dcn.2022.101120, Citations: 0
# DOI: 10.1016/j.dcn.2018.03.005, Citations: 0
# DOI: 10.1017/s0033291723001472, Citations: 0
# DOI: 10.2196/29426, Citations: 0
# DOI: 10.1016/s2352-4642(18)30278-5, Citations: 0
# DOI: 10.1162/imag/a/00037, Citations: 0
# DOI: 10.1016/j.dcn.2022.101195, Citations: 0
# DOI: 10.1017/s0033291723001472, Citations: 0
# DOI: 10.2196/29426, Citations: 0
# DOI: 10.1016/s2352-4642(18)30278-5, Citations: 0
# DOI: 10.1162/imag/a/00037, Citations: 0
# DOI: 10.1016/j.dcn.2022.101195, Citations: 0
# DOI: 10.1556/2006.2022.00044, Citations: 0
# DOI: 10.1556/2006.2023.00006, Citations: 0
# DOI: 10.1556/2006.2024.00016, Citations: 0
# DOI: 10.1186/s12966-024-01587-6, Citations: 0
# Total citations for group 0: 0
# DOI: 10.1556/2006.2022.00044, Citations: 0
# DOI: 10.1556/2006.2023.00006, Citations: 0
# DOI: 10.1556/2006.2024.00016, Citations: 0
# DOI: 10.1186/s12966-024-01587-6, Citations: 0
# Total citations for group 0: 0

# %%
results = []
for group_idx, doi_list in enumerate(groups):
    total_citations = 0
    for doi in doi_list:
        try:
            count = get_citations_for_doi(doi)
            total_citations += count
        except Exception as e:
            print(f"Error for DOI {doi}: {e}")
    results.append({'group': group_idx, 'total_citations': total_citations})
result_df = pd.DataFrame(results)
result_df.set_index('group', inplace=True)
result_df.to_csv('citations_by_group.csv')
print("Saved citation counts to citations_by_group.csv")
# Out:
# Saved citation counts to citations_by_group.csv
